# %%
import pandas as pd
pd.read_pickle('analysis_container/src/data/output/df_score.pkl')
# Out:
#                      model        type     score  precision    recall  \
# 6   DecisionTreeClassifier     Default  0.905800   0.909100  0.833300
# 7   RandomForestClassifier     Default  0.901300   0.869000  0.869000
# 3     KNeighborsClassifier     Default  0.878900   0.827600  0.857100
# 8           LGBMClassifier  GridSearch  0.837262   0.790500  0.747700
# 10           XGBClassifier  GridSearch  0.833895   0.796300  0.774800
# 0       LogisticRegression     Default  0.829600   0.780500  0.761900
# 11           XGBClassifier     Default  0.829367   0.810433  0.725067
# 1                LinearSVC     Default  0.820600   0.768300  0.750000
# 2                      SVC     Default  0.820600   0.775000  0.738100
# 5               Perceptron     Default  0.807200   0.766200  0.702400
# 4               GaussianNB     Default  0.802700   0.708300  0.809500
# 9           LGBMClassifier     Default  0.008305   0.814067  0.724100
#
# ...
